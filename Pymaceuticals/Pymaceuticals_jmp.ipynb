# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Observations and Insights
# - *Your observations and insights here* ...

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
df=pd.merge(mouse_metadata,study_results,on="Mouse ID",how='inner')
# Display the data table for preview
df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %%
# Checking the number of mice.
mouseCount = len(df['Mouse ID'].value_counts())
print(mouseCount)
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
df['Duplicate'] = df.duplicated()
dupes = df.loc[df['Duplicate']==True]
dupes
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
#
#      Tumor Volume (mm3)  Metastatic Sites  Duplicate
# 909                45.0                 0       True

# %%
# Optional: Get all the data for the duplicate mouse ID.

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
df_clean=df.loc[df['Mouse ID']!='g989']
df_clean=df_clean.drop('Duplicate', axis=1)
df_clean
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1880 rows x 8 columns]

# %%
# Checking the number of mice in the clean DataFrame.
mouseCount = len(df_clean['Mouse ID'].value_counts())
mouseCount
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

regGroups = df_clean.groupby('Drug Regimen')
regTumorAvg = regGroups['Tumor Volume (mm3)'].mean()
regTumorMedian = regGroups['Tumor Volume (mm3)'].median()
regTumorVar = regGroups['Tumor Volume (mm3)'].var()
regTumorStDev = regGroups['Tumor Volume (mm3)'].std()
regTumorSEM = regGroups['Tumor Volume (mm3)'].sem()

TumorVolSummary = pd.DataFrame({'Mean Volume':regTumorAvg,
                                'Median Volume':regTumorMedian,
                                'Tumor Volume Variance':regTumorVar,
                                'Tumor Volume Std. Dev':regTumorStDev,
                                'Tumor Volume Std. Err.':regTumorSEM
    
})
TumorVolSummary
# Out:
#               Mean Volume  Median Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin       40.675741      41.557809              24.947764
# Ceftamin        52.591172      51.776157              39.290177
# Infubinol       52.884795      51.820584              43.128684
# Ketapril        55.235638      53.698743              68.553577
# Naftisol        54.331565      52.509285              66.173479
# Placebo         54.033581      52.288934              61.168083
# Propriva        52.320930      50.446266              43.852013
# Ramicane        40.216745      40.673236              23.486704
# Stelasyn        54.233149      52.431737              59.450562
# Zoniferol       53.236507      51.818479              48.533355
#
#               Tumor Volume Std. Dev  Tumor Volume Std. Err.
# Drug Regimen
# Capomulin                  4.994774                0.329346
# Ceftamin                   6.268188                0.469821
# Infubinol                  6.567243                0.492236
# Ketapril                   8.279709                0.603860
# Naftisol                   8.134708                0.596466
# Placebo                    7.821003                0.581331
# Propriva                   6.622085                0.544332
# Ramicane                   4.846308                0.320955
# Stelasyn                   7.710419                0.573111
# Zoniferol                  6.966589                0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
df_clean.groupby('Drug Regimen').agg({'Tumor Volume (mm3)':['mean','median','var','std','sem']})
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.
drugMeasurements = df_clean.groupby('Drug Regimen')['Timepoint'].count()
drugMeasurements.plot(kind='bar')
plt.xlabel('Drug Regimen')
plt.ylabel('Number of Timepoint Measurements')
plt.tight_layout()

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using using pyplot.
measurementCount = drugMeasurements.to_list()
drugNames = [x for x in drugMeasurements.index]
x_axis=np.arange(len(drugNames))
plt.bar(x_axis,measurementCount,align='center')
plt.xticks(x_axis, drugNames, rotation='vertical')
plt.xlabel('Drug Regimen')
plt.ylabel('Number of Timepoint Measurements')
plt.tight_layout()
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
mouseSexes = df_clean['Sex'].value_counts()
mouseSexes.plot(kind='pie', autopct='%1.1f%%')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
mouseSexesLabels = [x for x in mouseSexes.index]
mouseSexesCounts = [x for x in mouseSexes]
plt.pie(mouseSexesCounts, labels=mouseSexesLabels, autopct='%1.1f%%')
plt.ylabel('Sex')
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

mouseGroups = df_clean.groupby(['Drug Regimen','Mouse ID'])
# Start by getting the last (greatest) timepoint for each mouse
mouseLastTime = mouseGroups['Timepoint'].max()
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
lastTumor = pd.merge(mouseLastTime,df,on=['Mouse ID','Timepoint'],how='left')
lastTumor = lastTumor.drop('Duplicate', axis=1)
# lastTumor = lastTumor.loc[(lastTumor['Drug Regimen']=='Capomulin' or lastTumor['Drug Regimen']=='Ramicane')]
lastTumor.head()
# Out:
#   Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0     b128         45    Capomulin  Female           9          22
# 1     b742         45    Capomulin    Male           7          21
# 2     f966         20    Capomulin    Male          16          17
# 3     g288         45    Capomulin    Male           3          19
# 4     g316         45    Capomulin  Female          22          22
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           38.982878                 2
# 1           38.939633                 0
# 2           30.485985                 0
# 3           37.074024                 1
# 4           40.159220                 2

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatment_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_list = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for drug in treatment_list:
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    tumorVol = lastTumor.loc[lastTumor['Drug Regimen']==drug]
    # add subset 
    tumor_vol_list.append(tumorVol['Tumor Volume (mm3)'])
    # Determine outliers using upper and lower bounds
    quarts = tumor_vol_list[treatment_list.index(drug)].quantile([.25,.5,.75])
    lowerQ = quarts[0.25]
    upperQ = quarts[0.75]
    iqr = upperQ-lowerQ
    lowerBound = lowerQ - (1.5*iqr)
    upperBound = upperQ + (1.5*iqr)
    drugSeries=tumor_vol_list[treatment_list.index(drug)]
    lowerOutliers = drugSeries.loc[drugSeries<=lowerBound]
    upperOutliers = drugSeries.loc[drugSeries>=upperBound]
    #Print a summary of data found for each drug regimen
    print(f"Summary for {drug}\nFirst Quartile: {lowerQ}, Third Quartile: {upperQ}\nLower Bound: {lowerBound}, Upper Bound: {upperBound}")
    if len(lowerOutliers)>0:
        print(f"The lower outliers for Tumor Volume (mm3) for {drug} are: \n{lowerOutliers}")
    if len(upperOutliers)>0:
        print(f"The upper outliers for Tumor Volume (mm3) for {drug} are: \n{upperOutliers}")
    print(f"----------------------")
# Out:
# Summary for Capomulin
# First Quartile: 32.37735684, Third Quartile: 40.1592203
# Lower Bound: 20.70456164999999, Upper Bound: 51.83201549
# ----------------------
# Summary for Ramicane
# First Quartile: 31.56046955, Third Quartile: 40.65900627
# Lower Bound: 17.912664470000003, Upper Bound: 54.30681135
# ----------------------
# Summary for Infubinol
# First Quartile: 54.04860769, Third Quartile: 65.52574285
# Lower Bound: 36.83290494999999, Upper Bound: 82.74144559000001
# The lower outliers for Tumor Volume (mm3) for Infubinol are:
# 55    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# ----------------------
# Summary for Ceftamin
# First Quartile: 48.72207785, Third Quartile: 64.29983003
# Lower Bound: 25.355449580000002, Upper Bound: 87.66645829999999
# ----------------------

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
fig1, ax1 = plt.subplots()
redCircles = dict(markerfacecolor='r', marker='o', markersize=12)
ax1.boxplot(tumor_vol_list, labels=treatment_list, flierprops=redCircles)
#ax1.set_xlabel(treatment_list)
ax1.set_ylabel('Final Tumor Volume (mm3)')
plt.tight_layout()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
capomulinMice=df_clean.loc[df_clean['Drug Regimen']=='Capomulin'].reset_index()
firstMouse = capomulinMice.iloc[0]
firstMouseID = firstMouse['Mouse ID']
firstMouseData = capomulinMice.loc[capomulinMice['Mouse ID']==firstMouseID]
x_values=firstMouseData['Timepoint']
y_values=firstMouseData['Tumor Volume (mm3)']
plt.plot(x_values, y_values)
plt.xlabel('Timepoint (days)')
plt.ylabel('Tumor Volume (mm3)')
plt.title(f'Capomulin treatment of mouse {firstMouseID}')
plt.tight_layout()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
capGroups = capomulinMice.groupby('Mouse ID')
mouseWeight = capGroups['Weight (g)'].unique()
mouseTumorVols = capGroups['Tumor Volume (mm3)'].mean()
plt.scatter(mouseWeight,mouseTumorVols)
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.tight_layout()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
